# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\HP\\Downloads\\Admission Chance.csv")

# %%
print("Our data set " , df)
# Out:
# Our data set       Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No          400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4    SOP               400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB
#         Serial No   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# ...

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='GRE_Score', y='Chance_of_Admit', data=df)
plt.title('GRE Score vs Chance of Admit')
plt.show()

# %%
sns.boxplot(x='Research', y='Chance_of_Admit', data=df)
plt.title('Research vs Chance of Admit')
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
avg_admit_by_uni = df.groupby('University_Rating')['Chance_of_Admit'].mean().reset_index()

sns.barplot(x='University_Rating', y='Chance_of_Admit', data=avg_admit_by_uni)
plt.title('Average Admit Chance by University Rating')
plt.show()
